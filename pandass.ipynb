# %% [markdown]
# <a href="https://colab.research.google.com/github/Kirtanaaa/MLTOOLS/blob/main/pandass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
iris_df=pd.read_csv("irisdata.csv")
print(iris_df)
print(type(iris_df))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
data_frame=iris_df.copy()

# %%
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data_frame.tail(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
print(data_frame.shape)
# Out:
# (150, 5)

# %%
print(data_frame.dtypes)
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
data_frame.species # or data_frame["species"]
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
data_frame.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
data_frame.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data_frame.iloc[0:3,0:2]
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2

# %%
rev=iris_df.copy()

# %%
data_frame.drop(0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]

# %%
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
rev.drop(0,inplace=True)

# %%
rev.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
data_frame.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris_df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
rev.index
# Out:
# RangeIndex(start=1, stop=150, step=1)

# %%
rev.drop(rev.index[0],inplace=True)
rev.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
rev.petal_width > 0.2
# Out:
# 2      False
# 3      False
# 4      False
# 5       True
# 6       True
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: petal_width, Length: 148, dtype: bool

# %%
rev[rev.petal_width > 0.2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [116 rows x 5 columns]

# %%
rev.describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width    species
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [148 rows x 5 columns]>

# %%
rev[rev.petal_width > 0.2].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    116.000000   116.000000    116.000000   116.000000
# mean       6.105172     2.963793      4.438793     1.496552
# std        0.740369     0.419606      1.402406     0.599410
# min        4.500000     2.000000      1.300000     0.300000
# 25%        5.600000     2.700000      4.000000     1.200000
# 50%        6.100000     3.000000      4.700000     1.500000
# 75%        6.600000     3.200000      5.400000     1.925000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data_frame[data_frame.species == 'virginica']
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
data_frame[data_frame.species == 'virginica'].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
print(rev.head())
print(rev.iloc[0]) #indexes
print(rev.loc[0])  #labels, the label starsts from 2, there is no 0
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     390                 try:
# --> 391                     return self._range.index(new_key)
#     392                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# ...

# %%
print(rev.loc[2])
# Out:
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object

# %%
rev.loc[0] = [4.5, 3.1, 1.5, 0.3, "setosa"]
rev.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
rev.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
# 0             4.5          3.1           1.5          0.3     setosa

# %%
rev.reset_index(inplace=True)

# %%
print(rev)
# Out:
#      index  sepal_length  sepal_width  petal_length  petal_width    species
# 0        2           4.7          3.2           1.3          0.2     setosa
# 1        3           4.6          3.1           1.5          0.2     setosa
# 2        4           5.0          3.6           1.4          0.2     setosa
# 3        5           5.4          3.9           1.7          0.4     setosa
# 4        6           4.6          3.4           1.4          0.3     setosa
# ..     ...           ...          ...           ...          ...        ...
# 144    146           6.3          2.5           5.0          1.9  virginica
# 145    147           6.5          3.0           5.2          2.0  virginica
# 146    148           6.2          3.4           5.4          2.3  virginica
# 147    149           5.9          3.0           5.1          1.8  virginica
# 148      0           4.5          3.1           1.5          0.3     setosa
#
# [149 rows x 6 columns]

# %%
rev.drop(columns="index",inplace=True)
print(rev)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             4.7          3.2           1.3          0.2     setosa
# 1             4.6          3.1           1.5          0.2     setosa
# 2             5.0          3.6           1.4          0.2     setosa
# 3             5.4          3.9           1.7          0.4     setosa
# 4             4.6          3.4           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 144           6.3          2.5           5.0          1.9  virginica
# 145           6.5          3.0           5.2          2.0  virginica
# 146           6.2          3.4           5.4          2.3  virginica
# 147           5.9          3.0           5.1          1.8  virginica
# 148           4.5          3.1           1.5          0.3     setosa
#
# [149 rows x 5 columns]

# %%
rev.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.845638     3.051678      3.775168     1.206040
# std        0.832327     0.433497      1.758758     0.760443
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
del rev["sepal_width"]
rev.describe()
# Out:
#        sepal_length  petal_length  petal_width
# count    149.000000    149.000000   149.000000
# mean       5.845638      3.775168     1.206040
# std        0.832327      1.758758     0.760443
# min        4.300000      1.000000     0.100000
# 25%        5.100000      1.600000     0.300000
# 50%        5.800000      4.400000     1.300000
# 75%        6.400000      5.100000     1.800000
# max        7.900000      6.900000     2.500000

# %%
rev["color"]="white"
print(rev)
# Out:
#      sepal_length  petal_length  petal_width    species  color
# 0             4.7           1.3          0.2     setosa  white
# 1             4.6           1.5          0.2     setosa  white
# 2             5.0           1.4          0.2     setosa  white
# 3             5.4           1.7          0.4     setosa  white
# 4             4.6           1.4          0.3     setosa  white
# ..            ...           ...          ...        ...    ...
# 144           6.3           5.0          1.9  virginica  white
# 145           6.5           5.2          2.0  virginica  white
# 146           6.2           5.4          2.3  virginica  white
# 147           5.9           5.1          1.8  virginica  white
# 148           4.5           1.5          0.3     setosa  white
#
# [149 rows x 5 columns]

# %%
rev.describe()
# Out:
#        sepal_length  petal_length  petal_width
# count    149.000000    149.000000   149.000000
# mean       5.845638      3.775168     1.206040
# std        0.832327      1.758758     0.760443
# min        4.300000      1.000000     0.100000
# 25%        5.100000      1.600000     0.300000
# 50%        5.800000      4.400000     1.300000
# 75%        6.400000      5.100000     1.800000
# max        7.900000      6.900000     2.500000

# %%
df=iris_df.copy()

# %%
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.iloc[2:3,2:4]=np.nan
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           NaN          NaN  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dropna(inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
df.reset_index(drop=True,inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.6          3.1           1.5          0.2  setosa
# 3           5.0          3.6           1.4          0.2  setosa
# 4           5.4          3.9           1.7          0.4  setosa

# %%
df.iloc[2:3,2:4]=np.nan
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.6          3.1           NaN          NaN  setosa
# 3           5.0          3.6           1.4          0.2  setosa
# 4           5.4          3.9           1.7          0.4  setosa

# %%
# find mean/median/mode or most occuring value
# find mean/median/mode or most occuring value for setosa

df.petal_length.fillna(df.petal_length.mean(),inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5      1.400000          0.2  setosa
# 1           4.9          3.0      1.400000          0.2  setosa
# 2           4.6          3.1      3.790541          NaN  setosa
# 3           5.0          3.6      1.400000          0.2  setosa
# 4           5.4          3.9      1.700000          0.4  setosa

# %%
temp=df[df.species=="setosa"]
df.petal_width.fillna(temp.petal_width.mean(),inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5      1.400000     0.200000  setosa
# 1           4.9          3.0      1.400000     0.200000  setosa
# 2           4.6          3.1      3.790541     0.245833  setosa
# 3           5.0          3.6      1.400000     0.200000  setosa
# 4           5.4          3.9      1.700000     0.400000  setosa
