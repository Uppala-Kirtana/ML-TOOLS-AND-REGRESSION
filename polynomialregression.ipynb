# %% [markdown]
# <a href="https://colab.research.google.com/github/Kirtanaaa/MLTOOLS/blob/main/polynomialregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# y = a1x1 + (a1x1)^2 + a2(x1)^2 + a3(x1)^3 + ... + (anx1)^n
#
# Applications:
#
# 1. Growth rate of tissues. Progression of disease epidemics.
#
# 2. Distribution of carbon isotopes in lake sediments.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing Data Set

# %%
dataset = pd.read_csv('rbc.csv')
x = dataset.iloc[:, 0:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_reg = PolynomialFeatures(degree = 6)
x_poly = polynomial_reg.fit_transform(x)

linear_reg_2 = LinearRegression()
linear_reg_2.fit(x_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(x, y, color="lightblue")
plt.plot(x, linear_reg.predict(x), color = "blue")
plt.title("RBC - Linear Regression")
plt.xlabel("Age")
plt.ylabel("RBC")
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
plt.scatter(x, y, color="lightblue")
plt.plot(x, linear_reg_2.predict(x_poly), color = "blue")
plt.title("RBC - Polynomial Regression")
plt.xlabel("Age")
plt.ylabel("RBC")
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
linear_reg.predict([[6.5]])
# Out:
# array([1980.15863901])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
linear_reg_2.predict(polynomial_reg.fit_transform([[6.5]]))
# Out:
# array([878.06765741])
